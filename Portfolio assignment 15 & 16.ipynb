# %%
import pandas as pd
import seaborn as sns
import scipy.stats as st
import sklearn as sklearn
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import tree
import graphviz
import numpy as np

# %% [markdown]
# ## Assignment 15

# %%
penguins = sns.load_dataset("penguins")
penguins = penguins.dropna()
penguins.head()
# Out:
#   species     island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0  Adelie  Torgersen            39.1           18.7              181.0
# 1  Adelie  Torgersen            39.5           17.4              186.0
# 2  Adelie  Torgersen            40.3           18.0              195.0
# 4  Adelie  Torgersen            36.7           19.3              193.0
# 5  Adelie  Torgersen            39.3           20.6              190.0
#
#    body_mass_g     sex
# 0       3750.0    Male
# 1       3800.0  Female
# 2       3250.0  Female
# 4       3450.0  Female
# 5       3650.0    Male

# %%
penguins_train, penguins_test = train_test_split(penguins.fillna(value=1).dropna(), test_size=0.3, random_state=42, stratify=penguins['species'])
print(penguins_train.shape, penguins_test.shape)
# Out:
# (233, 7) (100, 7)

# %%
features= ['bill_length_mm', 'bill_depth_mm']
dt = DecisionTreeClassifier(max_depth = 3)
dt.fit(penguins[features], penguins['species'])
# Out:
# DecisionTreeClassifier(max_depth=3)

# %% [markdown]
# Use your decision tree model to make predictions for both the train and test set.

# %%
predictions_train = dt.predict(penguins_train[features])
predictions_train
# Out:
# array(['Gentoo', 'Chinstrap', 'Chinstrap', 'Gentoo', 'Adelie', 'Adelie',
#        'Adelie', 'Chinstrap', 'Adelie', 'Chinstrap', 'Adelie', 'Gentoo',
#        'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Gentoo', 'Adelie',
#        'Adelie', 'Gentoo', 'Gentoo', 'Adelie', 'Chinstrap', 'Chinstrap',
#        'Gentoo', 'Chinstrap', 'Adelie', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Gentoo', 'Adelie', 'Chinstrap', 'Adelie', 'Adelie',
#        'Chinstrap', 'Adelie', 'Adelie', 'Gentoo', 'Gentoo', 'Adelie',
#        'Adelie', 'Gentoo', 'Gentoo', 'Adelie', 'Adelie', 'Gentoo',
#        'Chinstrap', 'Adelie', 'Chinstrap', 'Chinstrap', 'Gentoo',
#        'Gentoo', 'Gentoo', 'Adelie', 'Chinstrap', 'Chinstrap', 'Gentoo',
#        'Adelie', 'Gentoo', 'Adelie', 'Chinstrap', 'Adelie', 'Gentoo',
#        'Chinstrap', 'Gentoo', 'Adelie', 'Gentoo', 'Chinstrap', 'Adelie',
#        'Adelie', 'Chinstrap', 'Adelie', 'Gentoo', 'Gentoo', 'Adelie',
# ...

# %%
predictions_test = dt.predict(penguins_test[features])
predictions_test
# Out:
# array(['Chinstrap', 'Gentoo', 'Gentoo', 'Gentoo', 'Adelie', 'Chinstrap',
#        'Chinstrap', 'Adelie', 'Adelie', 'Gentoo', 'Adelie', 'Gentoo',
#        'Adelie', 'Chinstrap', 'Adelie', 'Gentoo', 'Chinstrap', 'Adelie',
#        'Chinstrap', 'Adelie', 'Adelie', 'Chinstrap', 'Adelie', 'Gentoo',
#        'Gentoo', 'Gentoo', 'Chinstrap', 'Adelie', 'Adelie', 'Adelie',
#        'Adelie', 'Gentoo', 'Adelie', 'Gentoo', 'Gentoo', 'Chinstrap',
#        'Adelie', 'Adelie', 'Gentoo', 'Adelie', 'Gentoo', 'Adelie',
#        'Adelie', 'Gentoo', 'Adelie', 'Adelie', 'Gentoo', 'Gentoo',
#        'Chinstrap', 'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Gentoo',
#        'Adelie', 'Adelie', 'Adelie', 'Adelie', 'Chinstrap', 'Chinstrap',
#        'Chinstrap', 'Gentoo', 'Chinstrap', 'Adelie', 'Chinstrap',
#        'Gentoo', 'Gentoo', 'Chinstrap', 'Gentoo', 'Adelie', 'Gentoo',
#        'Gentoo', 'Adelie', 'Chinstrap', 'Adelie', 'Gentoo', 'Adelie',
# ...

# %%
def calculate_accuracy(predictions, actuals):
    if(len(predictions) != len(actuals)):
        raise Exception("The amount of predictions did not equal the amount of actuals")
    
    return (predictions == actuals).sum() / len(actuals)

# %%
predictionsOnTrainset = dt.predict(penguins_train[features])
predictionsOnTestset = dt.predict(penguins_test[features])

accuracyTrain = calculate_accuracy(predictionsOnTrainset, penguins_train.species)
accuracyTest = calculate_accuracy(predictionsOnTestset, penguins_test.species)

print("Accuracy on training set " + str(accuracyTrain))
print("Accuracy on test set " + str(accuracyTest))
# Out:
# Accuracy on training set 0.9356223175965666
# Accuracy on test set 0.97

# %% [markdown]
# !!!!! Is the accurracy different? Did you expect this difference?

# %%
def plot_tree_classification(model, features, class_names):
    # Generate plot data
    dot_data = tree.export_graphviz(model, out_file=None, 
                          feature_names=features,  
                          class_names=class_names,  
                          filled=True, rounded=True,  
                          special_characters=True)  

    # Turn into graph using graphviz
    graph = graphviz.Source(dot_data)  

    # Write out a pdf
    graph.render("decision_tree")

    # Display in the notebook
    return graph

# %%
plot_tree_classification(dt, features, np.sort(penguins.species.unique()))

# %% [markdown]
# ## Assignment 16

# %%
songs = pd.read_csv('songs.csv', index_col='Unnamed: 0', quotechar="`") 
genre_counts = songs['Genre'].value_counts()
songs
# Out:
#                                                  Title            Artist  \
# 1                                     Hey, Soul Sister             Train
# 2                                 Love The Way You Lie            Eminem
# 3                                              TiK ToK             Kesha
# 4                                          Bad Romance         Lady Gaga
# 5                                 Just the Way You Are        Bruno Mars
# ..                                                 ...               ...
# 599                Find U Again (feat. Camila Cabello)       Mark Ronson
# 600      Cross Me (feat. Chance the Rapper & PnB Rock)        Ed Sheeran
# 601  No Brainer (feat. Justin Bieber, Chance the Ra...         DJ Khaled
# 602    Nothing Breaks Like a Heart (feat. Miley Cyrus)       Mark Ronson
# 603                                   Kills You Slowly  The Chainsmokers
#
#                Genre  Year  BPM  Energy  Danceability  dB  Live  Valence  \
# ...

# %%
songs.Genre.value_counts()
# Out:
# dance pop                    327
# pop                           60
# canadian pop                  34
# barbadian pop                 15
# boy band                      15
# electropop                    13
# british soul                  11
# big room                      10
# canadian contemporary r&b      9
# neo mellow                     9
# art pop                        8
# complextro                     6
# hip pop                        6
# australian dance               6
# atl hip hop                    5
# australian pop                 5
# edm                            5
# permanent wave                 4
# latin                          4
# hip hop                        4
# colombian pop                  3
# tropical house                 3
# brostep                        2
# downtempo                      2
# electronic trap                2
# belgian edm                    2
# escape room                    2
# folk-pop                       2
# ...

# %%
unique_genres_mask = songs['Genre'].isin(genre_counts[genre_counts == 1].index)

# %%
songs = songs[~unique_genres_mask]
songs.Genre.value_counts()
# Out:
# C:\Users\julie\AppData\Local\Temp\ipykernel_6384\214526554.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   songs = songs[~unique_genres_mask]
# dance pop                    327
# pop                           60
# canadian pop                  34
# barbadian pop                 15
# boy band                      15
# electropop                    13
# british soul                  11
# big room                      10
# neo mellow                     9
# canadian contemporary r&b      9
# art pop                        8
# australian dance               6
# hip pop                        6
# complextro                     6
# atl hip hop                    5
# edm                            5
# australian pop                 5
# permanent wave                 4
# latin                          4
# hip hop                        4
# tropical house                 3
# colombian pop                  3
# downtempo                      2
# ...

# %%
songs_train, songs_test = train_test_split(songs.fillna(value=1).dropna(), test_size=0.3, random_state=42, stratify=songs['Genre'])
print(songs_train.shape, songs_test.shape)
# Out:
# (411, 14) (177, 14)

# %%
features= ['BPM', 'Energy', 'Popularity', 'Year']
dt = DecisionTreeClassifier(max_depth = 4)
dt.fit(songs[features], songs['Genre'])
# Out:
# DecisionTreeClassifier(max_depth=4)

# %%
predictions_train = dt.predict(songs_train[features])
predictions_train
# Out:
# array(['dance pop', 'dance pop', 'dance pop', 'dance pop', 'dance pop',
#        'dance pop', 'dance pop', 'dance pop', 'dance pop', 'dance pop',
#        'dance pop', 'dance pop', 'dance pop', 'dance pop',
#        'australian dance', 'pop', 'dance pop', 'dance pop', 'dance pop',
#        'dance pop', 'dance pop', 'dance pop', 'dance pop', 'dance pop',
#        'dance pop', 'dance pop', 'neo mellow', 'dance pop', 'neo mellow',
#        'dance pop', 'dance pop', 'dance pop', 'pop', 'dance pop',
#        'dance pop', 'dance pop', 'dance pop', 'dance pop', 'dance pop',
#        'dance pop', 'dance pop', 'dance pop', 'dance pop', 'dance pop',
#        'dance pop', 'dance pop', 'dance pop', 'dance pop', 'dance pop',
#        'dance pop', 'dance pop', 'dance pop', 'dance pop', 'dance pop',
#        'dance pop', 'dance pop', 'dance pop', 'neo mellow', 'dance pop',
#        'dance pop', 'dance pop', 'dance pop', 'dance pop', 'dance pop',
# ...

# %%
predictions_test = dt.predict(songs_test[features])
predictions_test
# Out:
# array(['pop', 'dance pop', 'dance pop', 'dance pop', 'pop', 'dance pop',
#        'dance pop', 'dance pop', 'dance pop', 'dance pop', 'dance pop',
#        'dance pop', 'dance pop', 'dance pop', 'dance pop', 'dance pop',
#        'dance pop', 'dance pop', 'dance pop', 'dance pop', 'pop',
#        'dance pop', 'dance pop', 'dance pop', 'dance pop', 'dance pop',
#        'dance pop', 'dance pop', 'dance pop', 'dance pop', 'dance pop',
#        'pop', 'dance pop', 'dance pop', 'dance pop', 'dance pop',
#        'dance pop', 'dance pop', 'dance pop', 'dance pop', 'dance pop',
#        'dance pop', 'dance pop', 'dance pop', 'big room', 'dance pop',
#        'dance pop', 'dance pop', 'dance pop', 'dance pop', 'pop',
#        'dance pop', 'australian dance', 'dance pop', 'dance pop', 'pop',
#        'dance pop', 'dance pop', 'dance pop', 'dance pop', 'dance pop',
#        'pop', 'dance pop', 'dance pop', 'neo mellow', 'dance pop',
# ...

# %%
predictionsOnTrainset = dt.predict(songs_train[features])
predictionsOnTestset = dt.predict(songs_test[features])

accuracyTrain = calculate_accuracy(predictionsOnTrainset, songs_train.Genre)
accuracyTest = calculate_accuracy(predictionsOnTestset, songs_test.Genre)

print("Accuracy on training set " + str(accuracyTrain))
print("Accuracy on test set " + str(accuracyTest))
# Out:
# Accuracy on training set 0.5888077858880778
# Accuracy on test set 0.6271186440677966

# %% [markdown]
# !!!!! Is the accurracy different? Did you expect this difference?

# %%
plot_tree_classification(dt, features, np.sort(songs.Genre.unique()))
