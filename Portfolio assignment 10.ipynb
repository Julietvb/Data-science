# %%
import seaborn as sns
import pandas as pd

# %%
songs = pd.read_csv('songs.csv', index_col='Unnamed: 0', quotechar="`")

# %%
songs
# Out:
#                                                  Title            Artist  \
# 1                                     Hey, Soul Sister             Train
# 2                                 Love The Way You Lie            Eminem
# 3                                              TiK ToK             Kesha
# 4                                          Bad Romance         Lady Gaga
# 5                                 Just the Way You Are        Bruno Mars
# ..                                                 ...               ...
# 599                Find U Again (feat. Camila Cabello)       Mark Ronson
# 600      Cross Me (feat. Chance the Rapper & PnB Rock)        Ed Sheeran
# 601  No Brainer (feat. Justin Bieber, Chance the Ra...         DJ Khaled
# 602    Nothing Breaks Like a Heart (feat. Miley Cyrus)       Mark Ronson
# 603                                   Kills You Slowly  The Chainsmokers
#
#                Genre  Year  BPM  Energy  Danceability  dB  Live  Valence  \
# 1         neo mellow  2010   97      89            67  -4     8       80
# 2    detroit hip hop  2010   87      93            75  -5    52       64
# 3          dance pop  2010  120      84            76  -3    29       71
# 4          dance pop  2010  119      92            70  -4     8       71
# 5                pop  2010  109      84            64  -5     9       43
# ..               ...   ...  ...     ...           ...  ..   ...      ...
# 599        dance pop  2019  104      66            61  -7    20       16
# 600              pop  2019   95      79            75  -6     7       61
# 601        dance pop  2019  136      76            53  -5     9       65
# 602        dance pop  2019  114      79            60  -6    42       24
# 603       electropop  2019  150      44            70  -9    13       23
#
#      Duration  Acousticness  Speechiness   Popularity
# 1         217            19             4          83
# 2         263            24            23          82
# 3         200            10            14          80
# 4         295             0             4          79
# 5         221             2             4          78
# ..        ...           ...           ...         ...
# 599       176             1             3          75
# 600       206            21            12          75
# 601       260             7            34          70
# 602       217             1             7          69
# 603       213             6             6          67
#
# [603 rows x 14 columns]

# %%
songsDataCorrelations = songs.corr()
songsDataCorrelations.style.background_gradient(cmap='coolwarm', axis=None).format(precision=2)
# Out:
# C:\Users\julie\AppData\Local\Temp\ipykernel_23780\279833481.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   songsDataCorrelations = songs.corr()
# <style type="text/css">
# #T_18946_row0_col0, #T_18946_row1_col1, #T_18946_row2_col2, #T_18946_row3_col3, #T_18946_row4_col4, #T_18946_row5_col5, #T_18946_row6_col6, #T_18946_row7_col7, #T_18946_row8_col8, #T_18946_row9_col9, #T_18946_row10_col10 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_18946_row0_col1, #T_18946_row1_col0, #T_18946_row7_col10, #T_18946_row10_col7 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_18946_row0_col2, #T_18946_row2_col0 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_18946_row0_col3, #T_18946_row1_col5, #T_18946_row3_col0, #T_18946_row4_col5, #T_18946_row5_col1, #T_18946_row5_col4 {
#   background-color: #c4d5f3;
#   color: #000000;
# }
# #T_18946_row0_col4, #T_18946_row4_col0 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# #T_18946_row0_col5, #T_18946_row5_col0 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_18946_row0_col6, #T_18946_row6_col0 {
#   background-color: #98b9ff;
#   color: #000000;
# }
# #T_18946_row0_col7, #T_18946_row7_col0 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_18946_row0_col8, #T_18946_row5_col7, #T_18946_row7_col5, #T_18946_row8_col0 {
#   background-color: #c7d7f0;
#   color: #000000;
# }
# #T_18946_row0_col9, #T_18946_row8_col9, #T_18946_row9_col0, #T_18946_row9_col8 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_18946_row0_col10, #T_18946_row10_col0 {
#   background-color: #e0dbd8;
#   color: #000000;
# }
# #T_18946_row1_col2, #T_18946_row2_col1, #T_18946_row6_col9, #T_18946_row9_col6 {
#   background-color: #ccd9ed;
#   color: #000000;
# }
# #T_18946_row1_col3, #T_18946_row3_col1 {
#   background-color: #96b7ff;
#   color: #000000;
# }
# #T_18946_row1_col4, #T_18946_row2_col5, #T_18946_row4_col1, #T_18946_row5_col2 {
#   background-color: #d7dce3;
#   color: #000000;
# }
# #T_18946_row1_col6, #T_18946_row6_col1 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_18946_row1_col7, #T_18946_row3_col5, #T_18946_row3_col9, #T_18946_row5_col3, #T_18946_row7_col1, #T_18946_row9_col3 {
#   background-color: #adc9fd;
#   color: #000000;
# }
# #T_18946_row1_col8, #T_18946_row8_col1 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_18946_row1_col9, #T_18946_row7_col9, #T_18946_row9_col1, #T_18946_row9_col7 {
#   background-color: #bfd3f6;
#   color: #000000;
# }
# #T_18946_row1_col10, #T_18946_row5_col6, #T_18946_row6_col5, #T_18946_row10_col1 {
#   background-color: #b7cff9;
#   color: #000000;
# }
# #T_18946_row2_col3, #T_18946_row3_col2 {
#   background-color: #d4dbe6;
#   color: #000000;
# }
# #T_18946_row2_col4, #T_18946_row4_col2 {
#   background-color: #f7aa8c;
#   color: #000000;
# }
# #T_18946_row2_col6, #T_18946_row6_col2 {
#   background-color: #f4c5ad;
#   color: #000000;
# }
# #T_18946_row2_col7, #T_18946_row7_col2 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_18946_row2_col8, #T_18946_row8_col2 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_18946_row2_col9, #T_18946_row9_col2 {
#   background-color: #c9d7f0;
#   color: #000000;
# }
# #T_18946_row2_col10, #T_18946_row10_col2 {
#   background-color: #a6c4fe;
#   color: #000000;
# }
# #T_18946_row3_col4, #T_18946_row4_col3 {
#   background-color: #dfdbd9;
#   color: #000000;
# }
# #T_18946_row3_col6, #T_18946_row6_col3 {
#   background-color: #f7b396;
#   color: #000000;
# }
# #T_18946_row3_col7, #T_18946_row7_col3 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_18946_row3_col8, #T_18946_row8_col3 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_18946_row3_col10, #T_18946_row10_col3 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_18946_row4_col6, #T_18946_row6_col4 {
#   background-color: #e7d7ce;
#   color: #000000;
# }
# #T_18946_row4_col7, #T_18946_row7_col4 {
#   background-color: #9bbcff;
#   color: #000000;
# }
# #T_18946_row4_col8, #T_18946_row8_col4 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_18946_row4_col9, #T_18946_row9_col4 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_18946_row4_col10, #T_18946_row10_col4 {
#   background-color: #d2dbe8;
#   color: #000000;
# }
# #T_18946_row5_col8, #T_18946_row8_col5 {
#   background-color: #9ebeff;
#   color: #000000;
# }
# #T_18946_row5_col9, #T_18946_row9_col5 {
#   background-color: #cfdaea;
#   color: #000000;
# }
# #T_18946_row5_col10, #T_18946_row10_col5 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_18946_row6_col7, #T_18946_row7_col6 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_18946_row6_col8, #T_18946_row8_col6 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_18946_row6_col10, #T_18946_row10_col6 {
#   background-color: #bbd1f8;
#   color: #000000;
# }
# #T_18946_row7_col8, #T_18946_row8_col7 {
#   background-color: #c6d6f1;
#   color: #000000;
# }
# #T_18946_row8_col10, #T_18946_row10_col8 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_18946_row9_col10, #T_18946_row10_col9 {
#   background-color: #aac7fd;
#   color: #000000;
# }
# </style>
# <table id="T_18946">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_18946_level0_col0" class="col_heading level0 col0" >Year</th>
#       <th id="T_18946_level0_col1" class="col_heading level0 col1" >BPM</th>
#       <th id="T_18946_level0_col2" class="col_heading level0 col2" >Energy</th>
#       <th id="T_18946_level0_col3" class="col_heading level0 col3" >Danceability</th>
#       <th id="T_18946_level0_col4" class="col_heading level0 col4" >dB</th>
#       <th id="T_18946_level0_col5" class="col_heading level0 col5" >Live</th>
#       <th id="T_18946_level0_col6" class="col_heading level0 col6" >Valence</th>
#       <th id="T_18946_level0_col7" class="col_heading level0 col7" >Duration</th>
#       <th id="T_18946_level0_col8" class="col_heading level0 col8" >Acousticness</th>
#       <th id="T_18946_level0_col9" class="col_heading level0 col9" >Speechiness </th>
#       <th id="T_18946_level0_col10" class="col_heading level0 col10" >Popularity</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_18946_level0_row0" class="row_heading level0 row0" >Year</th>
#       <td id="T_18946_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_18946_row0_col1" class="data row0 col1" >-0.10</td>
#       <td id="T_18946_row0_col2" class="data row0 col2" >-0.23</td>
#       <td id="T_18946_row0_col3" class="data row0 col3" >0.08</td>
#       <td id="T_18946_row0_col4" class="data row0 col4" >-0.13</td>
#       <td id="T_18946_row0_col5" class="data row0 col5" >-0.14</td>
#       <td id="T_18946_row0_col6" class="data row0 col6" >-0.12</td>
#       <td id="T_18946_row0_col7" class="data row0 col7" >-0.22</td>
#       <td id="T_18946_row0_col8" class="data row0 col8" >0.10</td>
#       <td id="T_18946_row0_col9" class="data row0 col9" >0.00</td>
#       <td id="T_18946_row0_col10" class="data row0 col10" >0.24</td>
#     </tr>
#     <tr>
#       <th id="T_18946_level0_row1" class="row_heading level0 row1" >BPM</th>
#       <td id="T_18946_row1_col0" class="data row1 col0" >-0.10</td>
#       <td id="T_18946_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_18946_row1_col2" class="data row1 col2" >0.13</td>
#       <td id="T_18946_row1_col3" class="data row1 col3" >-0.13</td>
#       <td id="T_18946_row1_col4" class="data row1 col4" >0.18</td>
#       <td id="T_18946_row1_col5" class="data row1 col5" >0.08</td>
#       <td id="T_18946_row1_col6" class="data row1 col6" >0.02</td>
#       <td id="T_18946_row1_col7" class="data row1 col7" >-0.03</td>
#       <td id="T_18946_row1_col8" class="data row1 col8" >-0.11</td>
#       <td id="T_18946_row1_col9" class="data row1 col9" >0.06</td>
#       <td id="T_18946_row1_col10" class="data row1 col10" >0.02</td>
#     </tr>
#     <tr>
#       <th id="T_18946_level0_row2" class="row_heading level0 row2" >Energy</th>
#       <td id="T_18946_row2_col0" class="data row2 col0" >-0.23</td>
#       <td id="T_18946_row2_col1" class="data row2 col1" >0.13</td>
#       <td id="T_18946_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_18946_row2_col3" class="data row2 col3" >0.17</td>
#       <td id="T_18946_row2_col4" class="data row2 col4" >0.54</td>
#       <td id="T_18946_row2_col5" class="data row2 col5" >0.19</td>
#       <td id="T_18946_row2_col6" class="data row2 col6" >0.41</td>
#       <td id="T_18946_ro

# %%
songs.plot(kind='scatter', x='dB', y='Energy')
# Out:
# <AxesSubplot: xlabel='dB', ylabel='Energy'>

# %% [markdown]
# Tussen het aantal dB en Energy zit een correlatie van 0.54, dit is de sterkste positieve correlatie uit deze database. Zoals in het scatter plot getoond wordt het energielevel verhoogd naarmate het aantal dB dichterbij 0 komt. Dit betekent dat energieke nummers vaak luider zijn dan rustigere nummers.

# %%
songs.plot(kind='scatter', x='Acousticness', y='Energy')
# Out:
# <AxesSubplot: xlabel='Acousticness', ylabel='Energy'>

# %% [markdown]
# Tussen de acousticness en de energie zit ook een correlatie. Dit is echter een negatieve correlate. Naarmate de acousticness verhoogd, daalt het energielevel van het nummer. Dit komt omdat akoustische nummers vaak langzamere nummers zijn.
